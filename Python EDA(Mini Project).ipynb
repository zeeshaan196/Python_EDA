# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
A = pd.read_csv(r"C:\Users\Zeeshii_96\Downloads\Project files\Ad_table (extra).csv")
A
# Out:
#             Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month  \
# 0         Bentley    Arnage         10_1  10_1$$1      2018          4
# 1         Bentley    Arnage         10_1  10_1$$2      2018          6
# 2         Bentley    Arnage         10_1  10_1$$3      2017         11
# 3         Bentley    Arnage         10_1  10_1$$4      2018          4
# 4         Bentley    Arnage         10_1  10_1$$5      2017         11
# ...           ...       ...          ...      ...       ...        ...
# 268250  Westfield     Sport         97_1  97_1$$1      2018          5
# 268251  Westfield     Sport         97_1  97_1$$2      2018          5
# 268252      Zenos       E10         99_1  99_1$$1      2018          3
# 268253      Zenos       E10         99_1  99_1$$2      2018          3
# 268254      Zenos       E10         99_1  99_1$$3      2018          5
#
#          Color  Reg_year     Bodytype Runned_Miles  ... Engine_power  \
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Zeeshii_96\\Desktop\\FSA - DA\\Pyhton Classes'

# %%
os.listdir(r"C:\Users\Zeeshii_96\Downloads\Project files")
# Out:
# ['Ad_table (extra).csv',
#  'Basic_table.csv',
#  'Image_table.csv',
#  'Price_table.csv',
#  'Sales_table.csv',
#  'Trim_table.csv']

# %%
B = pd.read_csv(r"C:\Users\Zeeshii_96\Downloads\Project files\Basic_table.csv")
B
# Out:
#       Automaker  Automaker_ID    Genmodel Genmodel_ID
# 0            AC             1       Cobra         1_1
# 1        Abarth             2  124 Spider         2_1
# 2        Abarth             2         500         2_2
# 3        Abarth             2        500C         2_3
# 4        Abarth             2         595         2_4
# ...         ...           ...         ...         ...
# 1006  Westfield            97          XI        97_2
# 1007     Yamaha            98   Yxz 1000r        98_1
# 1008      Zenos            99         E10        99_1
# 1009      Acura           100          TL       100_1
# 1010     Alpine           101        A110       101_1
#
# [1011 rows x 4 columns]

# %%
C = pd.read_csv(r"C:\Users\Zeeshii_96\Downloads\Project files\Image_table.csv")
C
# Out:
#         Genmodel_ID     Image_ID  \
# 0               2_1    2_1$$1$$1
# 1               2_1  2_1$$10$$11
# 2               2_1  2_1$$10$$16
# 3               2_1  2_1$$10$$18
# 4               2_1   2_1$$10$$2
# ...             ...          ...
# 1451779        99_1   99_1$$3$$7
# 1451780        99_1   99_1$$1$$0
# 1451781        99_1   99_1$$1$$3
# 1451782        99_1   99_1$$1$$4
# 1451783        99_1   99_1$$1$$5
#
#                                                 Image_name  \
# 0        Abarth$$124 Spider$$2017$$Blue$$2_1$$1$$image_...
# 1        Abarth$$124 Spider$$2017$$Blue$$2_1$$10$$image...
# 2        Abarth$$124 Spider$$2017$$Blue$$2_1$$10$$image...
# 3        Abarth$$124 Spider$$2017$$Blue$$2_1$$10$$image...
# 4        Abarth$$124 Spider$$2017$$Blue$$2_1$$10$$image...
# ...                                                    ...
# 1451779       Zenos$$E10$$2016$$Grey$$99_1$$3$$image_7.jpg
# 1451780        Zenos$$E10$$2016$$Red$$99_1$$1$$image_0.jpg
# ...

# %%
D = pd.read_csv(r"C:\Users\Zeeshii_96\Downloads\Project files\Price_table.csv")
D
# Out:
#        Maker    Genmodel Genmodel_ID  Year  Entry_price
# 0     Abarth  124 Spider         2_1  2016        29365
# 1     Abarth  124 Spider         2_1  2017        26665
# 2     Abarth  124 Spider         2_1  2018        26665
# 3     Abarth  124 Spider         2_1  2019        29515
# 4     Abarth         500         2_2  2009        13400
# ...      ...         ...         ...   ...          ...
# 6328   Volvo         V50        96_9  2008        15780
# 6329   Volvo         V50        96_9  2009        15770
# 6330   Volvo         V50        96_9  2010        17465
# 6331   Volvo         V50        96_9  2011        17615
# 6332   Volvo         V50        96_9  2012        19375
#
# [6333 rows x 5 columns]

# %%
E = pd.read_csv(r"C:\Users\Zeeshii_96\Downloads\Project files\Sales_table.csv")
E
# Out:
#       Maker      Genmodel Genmodel_ID   2020   2019   2018   2017   2016  \
# 0    ABARTH    ABARTH 124         2_1      0     19     27     60      0
# 1    ABARTH    ABARTH 500         2_2      0      0      1      2     66
# 2    ABARTH    ABARTH 595         2_4   2144   2866   3907   3295   3132
# 3    ABARTH    ABARTH 695         2_6     45     65    270    114     29
# 4    ABARTH  ABARTH PUNTO         2_9      0      0      0      0      0
# ..      ...           ...         ...    ...    ...    ...    ...    ...
# 768   VOLVO    VOLVO XC40       96_20  24281  14894   6616      8      0
# 769   VOLVO    VOLVO XC60       96_16   7694  11182  10840  14994  14808
# 770   VOLVO    VOLVO XC70       96_17      0      0      0     17   1006
# 771   VOLVO    VOLVO XC90       96_18   4969   7495   6475   5564   5254
# 772   ZENOS     ZENOS E10        99_1      0      0      0      2     10
#
#       2015  2014  ...  2010  2009  2008  2007  2006  2005  2004  2003  2002  \
# ...

# %%
F = pd.read_csv(r"C:\Users\Zeeshii_96\Downloads\Project files\Trim_table.csv")
F
# Out:
#        Genmodel_ID   Maker    Genmodel  \
# 0              2_1  Abarth  124 spider
# 1              2_1  Abarth  124 spider
# 2              2_1  Abarth  124 spider
# 3              2_1  Abarth  124 spider
# 4              2_1  Abarth  124 spider
# ...            ...     ...         ...
# 335557       96_20   Volvo        Xc40
# 335558       96_20   Volvo        Xc40
# 335559       96_20   Volvo        Xc40
# 335560       96_20   Volvo        Xc40
# 335561       96_20   Volvo        Xc40
#
#                                                      Trim  Year  Price  \
# 0                   124 Spider1.4 Turbo MultiAir 170hp 2d  2016  29365
# 1       124 Spider1.4 Turbo MultiAir 170hp Sequenziale...  2016  31365
# 2                   124 Spider1.4 Turbo MultiAir 170hp 2d  2017  29365
# 3       124 Spider1.4 Turbo MultiAir 170hp Sequenziale...  2017  31365
# 4         124 SpiderScorpione 1.4 Turbo MultiAir 170hp 2d  2017  26665
# ...

# %% [markdown]
# # ADVERTISE DATA SET

# %%
pd.set_option('Display.Max_columns',100)
A
# Out:
#             Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month  \
# 0         Bentley    Arnage         10_1  10_1$$1      2018          4
# 1         Bentley    Arnage         10_1  10_1$$2      2018          6
# 2         Bentley    Arnage         10_1  10_1$$3      2017         11
# 3         Bentley    Arnage         10_1  10_1$$4      2018          4
# 4         Bentley    Arnage         10_1  10_1$$5      2017         11
# ...           ...       ...          ...      ...       ...        ...
# 268250  Westfield     Sport         97_1  97_1$$1      2018          5
# 268251  Westfield     Sport         97_1  97_1$$2      2018          5
# 268252      Zenos       E10         99_1  99_1$$1      2018          3
# 268253      Zenos       E10         99_1  99_1$$2      2018          3
# 268254      Zenos       E10         99_1  99_1$$3      2018          5
#
#          Color  Reg_year     Bodytype Runned_Miles Engin_size    Gearbox  \
# ...

# %%
A['Maker'].unique()
# Out:
# array(['Bentley', 'Brooke', 'Bugatti', 'Cadillac', 'Caterham',
#        'Chevrolet', 'Chrysler', 'Citroen', 'Corvette', 'DAX', 'DS',
#        'Dacia', 'Daewoo', 'Daihatsu', 'Daimler', 'Dodge', 'Ferrari',
#        'Fiat', 'Ford', 'Abarth', 'GMC', 'Ginetta', 'Great Wall',
#        'Grinnall', 'Honda', 'Hummer', 'Hyundai', 'Infiniti', 'Isuzu',
#        'Jaguar', 'Jeep', 'Jensen', 'KTM', 'Kia', 'Koenigsegg',
#        'Lamborghini', 'Land Rover', 'Lexus', 'Lincoln', 'Alfa Romeo',
#        'London Taxis International', 'Lotus', 'MEV', 'MG', 'MINI',
#        'Maserati', 'Maybach', 'Mazda', 'McLaren', 'Mercedes-Benz',
#        'Mitsubishi', 'Morgan', 'Nissan', 'Noble', 'Opel', 'Pagani',
#        'Perodua', 'Peugeot', 'Aston Martin', 'Pilgrim', 'Porsche',
#        'Proton', 'Radical', 'Raw', 'Renault', 'Reva', 'Rolls-Royce',
#        'Rover', 'SEAT', 'Audi', 'SKODA', 'Saab', 'Santana', 'Sebring',
#        'Smart', 'Ssangyong', 'Subaru', 'Suzuki', 'TVR', 'BMW', 'Tesla',
# ...

# %%
A['Maker'].nunique()
# Out:
# 88

# %%
A[' Genmodel'].nunique()
# Out:
# 896

# %%
A['Maker'].value_counts().reset_index().sort_values(by = 'count',ascending = False)
# Out:
#          Maker  count
# 0         Ford  26937
# 1         Audi  22521
# 2     Vauxhall  20158
# 3   Volkswagen  17999
# 4          BMW  17194
# ..         ...    ...
# 83         Raw      1
# 84        Reva      1
# 85     Pilgrim      1
# 86     Sebring      1
# 87     Santana      1
#
# [88 rows x 2 columns]

# %%
len(A.columns)
# Out:
# 24

# %%
AB = A.groupby(['Maker','Bodytype','Gearbox'])['Price'].value_counts().reset_index().sort_values(by = 'count' , ascending = False)
AB
# Out:
#            Maker   Bodytype Gearbox    Price  count
# 33077       Ford  Hatchback  Manual    995.0    219
# 110592  Vauxhall  Hatchback  Manual   3995.0    171
# 33078       Ford  Hatchback  Manual   1495.0    162
# 110593  Vauxhall  Hatchback  Manual   4995.0    153
# 33079       Ford  Hatchback  Manual   1995.0    130
# ...          ...        ...     ...      ...    ...
# 128420     Volvo     Saloon  Manual  19695.0      1
# 128421     Volvo     Saloon  Manual  19795.0      1
# 128422     Volvo     Saloon  Manual  19999.0      1
# 128423     Volvo     Saloon  Manual  20000.0      1
# 128424     Volvo     Saloon  Manual  20295.0      1
#
# [128441 rows x 5 columns]

# %%
A.head()
# Out:
#      Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley    Arnage         10_1  10_1$$1      2018          4  Silver
# 1  Bentley    Arnage         10_1  10_1$$2      2018          6    Grey
# 2  Bentley    Arnage         10_1  10_1$$3      2017         11    Blue
# 3  Bentley    Arnage         10_1  10_1$$4      2018          4   Green
# 4  Bentley    Arnage         10_1  10_1$$5      2017         11    Grey
#
#    Reg_year Bodytype Runned_Miles Engin_size    Gearbox Fuel_type    Price  \
# 0    2000.0   Saloon        60000       6.8L  Automatic    Petrol  21500.0
# 1    2002.0   Saloon        44000       6.8L  Automatic    Petrol  28750.0
# 2    2002.0   Saloon        55000       6.8L  Automatic    Petrol  29999.0
# 3    2003.0   Saloon        14000       6.8L  Automatic    Petrol  34948.0
# 4    2003.0   Saloon        61652       6.8L  Automatic    Petrol  26555.0
#
#    Engine_power Annual_Tax  Wheelbase  Height   Width  Length Average_mpg  \
# ...

# %%
BC = A.groupby(['Maker','Color','Gearbox'])['Reg_year'].value_counts().reset_index()
BC
# Out:
#            Maker   Color    Gearbox  Reg_year  count
# 0         Abarth   Black  Automatic    2015.0      1
# 1         Abarth   Black  Automatic    2016.0      1
# 2         Abarth   Black  Automatic    2017.0      1
# 3         Abarth   Black  Automatic    2018.0      1
# 4         Abarth   Black     Manual    2015.0     13
# ...          ...     ...        ...       ...    ...
# 11357      Volvo  Yellow     Manual    2012.0      1
# 11358  Westfield  Yellow     Manual    2006.0      2
# 11359      Zenos   Green     Manual    2016.0      1
# 11360      Zenos    Grey     Manual    2016.0      1
# 11361      Zenos     Red     Manual    2016.0      1
#
# [11362 rows x 5 columns]

# %%
# Example for count (count shows entire units done in that year)
A.groupby(['Maker','Color'])['Reg_year'].count().reset_index()
# Out:
#          Maker        Color  Reg_year
# 0       Abarth        Black        59
# 1       Abarth         Blue        50
# 2       Abarth        Green         5
# 3       Abarth         Grey       100
# 4       Abarth  Multicolour         5
# ..         ...          ...       ...
# 807      Volvo       Yellow         3
# 808  Westfield       Yellow         2
# 809      Zenos        Green         1
# 810      Zenos         Grey         1
# 811      Zenos          Red         1
#
# [812 rows x 3 columns]

# %%
# Example for value_count (val_cnt : checks for each Reg_year counts)
A.groupby(['Maker','Color'])['Reg_year'].value_counts().reset_index()
# Out:
#           Maker   Color  Reg_year  count
# 0        Abarth   Black    2015.0     14
# 1        Abarth   Black    2016.0     11
# 2        Abarth   Black    2019.0     10
# 3        Abarth   Black    2014.0      8
# 4        Abarth   Black    2017.0      8
# ...         ...     ...       ...    ...
# 7173      Volvo  Yellow    2012.0      1
# 7174  Westfield  Yellow    2006.0      2
# 7175      Zenos   Green    2016.0      1
# 7176      Zenos    Grey    2016.0      1
# 7177      Zenos     Red    2016.0      1
#
# [7178 rows x 4 columns]

# %%
plt.figure(figsize = (16,8))
sns.barplot(x ='Bodytype' , y = 'count' , data = AB,hue = 'Gearbox' )
plt.legend
plt.title('REPORT on Bodytypes count ACCORDING TO TRANSMISSION' , color = 'red')
plt.xticks(rotation = 90 , color = 'blue')
plt.show()

# %%
plt.figure(figsize = (16,8))
sns.barplot(x ='Color' , y = 'count' , data = BC , hue = 'Gearbox'  )
plt.xticks(rotation = 90)
plt.title('REPORT ON TRANSMISSION TYPES According to Colors')
plt.show()

# %%
plt.figure(figsize = (16,7))
sns.histplot(AB['Price'] , kde = True , bins = 10000 )
plt.show()

# %%
AB = A.groupby(['Maker','Bodytype','Gearbox'])['Price'].value_counts().reset_index().sort_values(by = 'count' , ascending = False).head()
AB
# Out:
#            Maker   Bodytype Gearbox   Price  count
# 33077       Ford  Hatchback  Manual   995.0    219
# 110592  Vauxhall  Hatchback  Manual  3995.0    171
# 33078       Ford  Hatchback  Manual  1495.0    162
# 110593  Vauxhall  Hatchback  Manual  4995.0    153
# 33079       Ford  Hatchback  Manual  1995.0    130

# %%
plt.pie(AB['count'] , labels = AB['Gearbox'] ,shadow = True, autopct= '%1.2f%%' ,explode = [0.6,0,0,0,0])
plt.show()

# %%
A.head()
# Out:
#      Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley    Arnage         10_1  10_1$$1      2018          4  Silver
# 1  Bentley    Arnage         10_1  10_1$$2      2018          6    Grey
# 2  Bentley    Arnage         10_1  10_1$$3      2017         11    Blue
# 3  Bentley    Arnage         10_1  10_1$$4      2018          4   Green
# 4  Bentley    Arnage         10_1  10_1$$5      2017         11    Grey
#
#    Reg_year Bodytype Runned_Miles Engin_size    Gearbox Fuel_type    Price  \
# 0    2000.0   Saloon        60000       6.8L  Automatic    Petrol  21500.0
# 1    2002.0   Saloon        44000       6.8L  Automatic    Petrol  28750.0
# 2    2002.0   Saloon        55000       6.8L  Automatic    Petrol  29999.0
# 3    2003.0   Saloon        14000       6.8L  Automatic    Petrol  34948.0
# 4    2003.0   Saloon        61652       6.8L  Automatic    Petrol  26555.0
#
#    Engine_power Annual_Tax  Wheelbase  Height   Width  Length Average_mpg  \
# ...

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268255 entries, 0 to 268254
# Data columns (total 24 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Maker         268255 non-null  object
#  1    Genmodel     268255 non-null  object
#  2    Genmodel_ID  268255 non-null  object
#  3   Adv_ID        268255 non-null  object
#  4   Adv_year      268255 non-null  int64
#  5   Adv_month     268255 non-null  int64
#  6   Color         246380 non-null  object
#  7   Reg_year      268248 non-null  float64
#  8   Bodytype      267301 non-null  object
#  9   Runned_Miles  267200 non-null  object
#  10  Engin_size    266191 non-null  object
#  11  Gearbox       268088 non-null  object
#  12  Fuel_type     267846 non-null  object
#  13  Price         267110 non-null  float64
#  14  Engine_power  236444 non-null  float64
#  15  Annual_Tax    221580 non-null  object
#  16  Wheelbase     240257 non-null  float64
# ...

# %%
A.describe()
# Out:
#             Adv_year      Adv_month       Reg_year         Price  \
# count  268255.000000  268255.000000  268248.000000  2.671100e+05
# mean     2018.127778       5.626143    2012.708430  1.475626e+04
# std         0.747476       2.091577       4.465705  3.232091e+04
# min      2012.000000       1.000000    1900.000000  1.000000e+02
# 25%      2018.000000       4.000000    2010.000000  4.990000e+03
# 50%      2018.000000       5.000000    2014.000000  9.299000e+03
# 75%      2018.000000       7.000000    2016.000000  1.715000e+04
# max      2021.000000      33.000000    2019.000000  9.999999e+06
#
#         Engine_power      Wheelbase         Height          Width  \
# count  236444.000000  240257.000000  240454.000000  240175.000000
# mean      150.545834    2564.547056    1530.675081    1896.004559
# std        84.476285     490.002254     163.947099     150.998397
# min        17.000000       0.000000       0.000000    1191.000000
# ...

# %%
A.isnull().any()
# Out:
# Maker           False
#  Genmodel       False
#  Genmodel_ID    False
# Adv_ID          False
# Adv_year        False
# Adv_month       False
# Color            True
# Reg_year         True
# Bodytype         True
# Runned_Miles     True
# Engin_size       True
# Gearbox          True
# Fuel_type        True
# Price            True
# Engine_power     True
# Annual_Tax       True
# Wheelbase        True
# Height           True
# Width            True
# Length           True
# Average_mpg      True
# Top_speed        True
# Seat_num         True
# Door_num         True
# dtype: bool

# %%
A['Wheelbase'] = A['Wheelbase'].fillna(A['Wheelbase'].median())

# %%
A.isnull().any()
# Out:
# Maker           False
#  Genmodel       False
#  Genmodel_ID    False
# Adv_ID          False
# Adv_year        False
# Adv_month       False
# Color            True
# Reg_year         True
# Bodytype         True
# Runned_Miles     True
# Engin_size       True
# Gearbox          True
# Fuel_type        True
# Price            True
# Engine_power     True
# Annual_Tax       True
# Wheelbase       False
# Height           True
# Width            True
# Length           True
# Average_mpg      True
# Top_speed        True
# Seat_num         True
# Door_num         True
# dtype: bool

# %%
sns.boxplot(A['Length'])
# Out:
# <Axes: ylabel='Length'>

# %%
# REMOVING OUTLIERS 
Q1 = A['Length'].quantile(0.25)
Q3 = A['Length'].quantile(0.75)
IQR = Q3 - Q1
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

# %%
lower_lim
# Out:
# np.float64(3194.5)

# %%
upper_lim
# Out:
# np.float64(5558.5)

# %%
sns.boxplot(Remove_outliers['Length'])
# Out:
# <Axes: ylabel='Length'>

# %%
Remove_outliers = A.loc[(A['Length'] > lower_lim) & (A['Length'] < upper_lim )]
Remove_outliers
# Out:
#           Maker  Genmodel  Genmodel_ID     Adv_ID  Adv_year  Adv_month  \
# 0       Bentley    Arnage         10_1    10_1$$1      2018          4
# 1       Bentley    Arnage         10_1    10_1$$2      2018          6
# 2       Bentley    Arnage         10_1    10_1$$3      2017         11
# 3       Bentley    Arnage         10_1    10_1$$4      2018          4
# 4       Bentley    Arnage         10_1    10_1$$5      2017         11
# ...         ...       ...          ...        ...       ...        ...
# 268245    Volvo       V50         96_9  96_9$$522      2018          7
# 268246    Volvo       V50         96_9  96_9$$523      2018          8
# 268247    Volvo       V50         96_9  96_9$$524      2018          5
# 268248    Volvo       V50         96_9  96_9$$525      2018          5
# 268249    Volvo       V50         96_9  96_9$$526      2018          1
#
#          Color  Reg_year Bodytype Runned_Miles Engin_size    Gearbox  \
# ...

# %%
A['Length'] = A['Length'].fillna(A['Length'].mean())

# %%
A['Length'].isnull().any()
# Out:
# np.False_

# %%
#DROPPING NAN VALUES 
A = A.dropna(subset =['Engine_power','Height','Width','Seat_num','Door_num'])

# %%
A['Engin_size'] = A['Engin_size'].fillna(A['Engin_size'].mode()[0])

# %%
for i in A['Runned_Miles']:
    i.split(' ')
    print(i)
# Out:
# 60000
# 44000
# 55000
# 14000
# 61652
# 55000
# 67000
# 99200
# 27541
# 38000
# 69491
# 52000
# 53444
# 58000
# 61500
# 49700
# 35000
# 75000
# 48226
# 92000
# 60000
# 51789
# 77000
# 75000
# 49968
# 98000
# 30000
# 40000
# 46000
# 47225
# 78000
# 12661
# 415
# 15141
# 3000
# 33000
# 500
# 10972
# 5963
# 1000
# 16526
# 16200
# 6000
# 15000
# 5900
# 9000
# 3000
# 5185
# 2810
# 20
# 40
# 80
# 10
# 2500
# 50
# 2000
# 2000
# 4944
# 1500
# 1496
# 700
# 12348
# 1000
# 6012
# 5734
# 8147
# 8500
# 150
# 2000
# 50
# 1125
# 19283
# 1500
# 13190
# 100
# 7982
# 3678
# 4323
# 6500
# 1800
# 5576
# 12042
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 2
#       1 for i in A['Runned_Miles']:
# ----> 2     i.split(' ')
#       3     print(i)
#
# AttributeError: 'float' object has no attribute 'split'

# %%
A.head()
# Out:
#      Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley    Arnage         10_1  10_1$$1      2018          4  Silver
# 1  Bentley    Arnage         10_1  10_1$$2      2018          6    Grey
# 2  Bentley    Arnage         10_1  10_1$$3      2017         11    Blue
# 3  Bentley    Arnage         10_1  10_1$$4      2018          4   Green
# 4  Bentley    Arnage         10_1  10_1$$5      2017         11    Grey
#
#    Reg_year Bodytype Runned_Miles Engin_size    Gearbox Fuel_type    Price  \
# 0    2000.0   Saloon        60000       6.8L  Automatic    Petrol  21500.0
# 1    2002.0   Saloon        44000       6.8L  Automatic    Petrol  28750.0
# 2    2002.0   Saloon        55000       6.8L  Automatic    Petrol  29999.0
# 3    2003.0   Saloon        14000       6.8L  Automatic    Petrol  34948.0
# 4    2003.0   Saloon        61652       6.8L  Automatic    Petrol  26555.0
#
#    Engine_power Annual_Tax  Wheelbase  Height   Width  Length Average_mpg  \
# ...

# %%
A['Extra_Runned_Miles'] = A['Runned_Miles'] * 2

# %%
#CONVERSION FROM STR to INT
A['Extra_Runned_Miles'] = pd.to_numeric(A['Extra_Runned_Miles'], errors='coerce')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,4))

# Few bins (5)
plt.subplot(1,3,1)
sns.histplot(A['Height'], kde=True, bins=5)
plt.title("bins = 5")

# Medium bins (20)
plt.subplot(1,3,2)
sns.histplot(A['Height'], kde=True, bins=20)
plt.title("bins = 20")

# Many bins (100)
plt.subplot(1,3,3)
sns.histplot(A['Height'], kde=True, bins=100)
plt.title("bins = 100")

plt.tight_layout()
plt.show()

# %%
# SEABORN PLOTTING FOR LINE , SCATTER , HISTOGRAM
CD = A.groupby(['Maker','Gearbox','Bodytype'])['Width'].value_counts().reset_index().sort_values(by = 'Width' ,ascending = False).head(30)
CD
# Out:
#               Maker    Gearbox     Bodytype   Width  count
# 986            Jeep  Automatic          SUV  2690.0      3
# 2044      Ssangyong     Manual          MPV  2365.0     11
# 2033      Ssangyong  Automatic          MPV  2365.0     40
# 2052      Ssangyong     Manual          SUV  2350.0     14
# 2040      Ssangyong  Automatic          SUV  2350.0     26
# 2422     Volkswagen     Manual    Combi Van  2283.0      3
# 2137          Tesla  Automatic          SUV  2271.0      9
# 1073    Lamborghini  Automatic        Coupe  2265.0      9
# 1435  Mercedes-Benz     Manual          MPV  2253.0      4
# 1370  Mercedes-Benz  Automatic          MPV  2253.0      8
# 1368  Mercedes-Benz  Automatic          MPV  2249.0     35
# 983            Jeep  Automatic          SUV  2239.0     12
# 1071    Lamborghini  Automatic        Coupe  2236.0     23
# 1068    Lamborghini  Automatic  Convertible  2236.0      8
# 2324       Vauxhall     Manual          MPV  2232.0      9
# ...

# %%
# SEABORN PLOTTING FOR LINE , SCATTER , HISTOGRAM
DE = A.groupby(['Maker' , 'Gearbox','Bodytype'])['Length'].value_counts().reset_index().sort_values(by = 'Length' , ascending = False).head(30)
DE
# Out:
#               Maker    Gearbox    Bodytype  Length  count
# 1792        Maybach  Automatic   Limousine  6165.0      3
# 2816    Rolls-Royce  Automatic   Limousine  6092.0      2
# 2820    Rolls-Royce  Automatic   Limousine  6084.0      1
# 1544     Land Rover  Automatic         SUV  5970.0    228
# 2819    Rolls-Royce  Automatic   Limousine  5842.0      1
# 2815    Rolls-Royce  Automatic   Limousine  5834.0     23
# 485         Bentley  Automatic      Saloon  5825.0      1
# 734           Dodge  Automatic      Pickup  5783.0      1
# 2818    Rolls-Royce  Automatic   Limousine  5762.0      1
# 1793        Maybach  Automatic   Limousine  5728.0      1
# 480         Bentley  Automatic      Saloon  5575.0     40
# 2075  Mercedes-Benz  Automatic      Saloon  5453.0      6
# 475         Bentley  Automatic       Coupe  5411.0      3
# 2797        Renault     Manual     Minibus  5399.0      1
# 2808        Renault     Manual  Window Van  5399.0      1
# ...

# %%
# MERGING 2 DATA's 
EF = pd.merge(CD , DE, on = 'Maker' , how = 'inner')
EF
# Out:
#             Maker  Gearbox_x   Bodytype_x   Width  count_x  Gearbox_y  \
# 0   Mercedes-Benz     Manual          MPV  2253.0        4  Automatic
# 1   Mercedes-Benz     Manual          MPV  2253.0        4  Automatic
# 2   Mercedes-Benz     Manual          MPV  2253.0        4  Automatic
# 3   Mercedes-Benz     Manual          MPV  2253.0        4     Manual
# 4   Mercedes-Benz  Automatic          MPV  2253.0        8  Automatic
# 5   Mercedes-Benz  Automatic          MPV  2253.0        8  Automatic
# 6   Mercedes-Benz  Automatic          MPV  2253.0        8  Automatic
# 7   Mercedes-Benz  Automatic          MPV  2253.0        8     Manual
# 8   Mercedes-Benz  Automatic          MPV  2249.0       35  Automatic
# 9   Mercedes-Benz  Automatic          MPV  2249.0       35  Automatic
# 10  Mercedes-Benz  Automatic          MPV  2249.0       35  Automatic
# 11  Mercedes-Benz  Automatic          MPV  2249.0       35     Manual
# ...

# %%
CD.columns
# Out:
# Index(['Maker', 'Gearbox', 'Bodytype', 'Width', 'count'], dtype='object')

# %%
plt.figure(figsize = (12,5))
sns.lineplot(x = 'Maker' , y = 'Width', data = CD  , lw = 3 , label = 'Width of Makers' , marker = 'X' , markersize = 9 )
sns.lineplot(x = 'Maker' , y = 'Length' , data = DE  , lw = 3 , label = 'Length of Makers' , marker = "o" , markersize = 8)
sns.lineplot(x = 'Maker' , y = 'count_x', data = EF  , lw = 5 , label = 'Count_x of Makers After Merge' , marker = '*' , markersize = 15 )
sns.lineplot(x = 'Maker' , y = 'count_y', data = EF  , lw = 5 , label = 'Count_y of Makers After Merge' , marker = '*' , markersize = 15 )
plt.xlabel('MAKERS' , color = 'violet')
plt.ylabel('Width and Length' , color = 'purple')
plt.xticks(rotation = 90)
plt.yticks(rotation = 45)
plt.title('REPORT OF MAKERS ON SIZE')
plt.grid(alpha = 0.8)
plt.show()

# %%
plt.figure(figsize = (11,5))
sns.scatterplot(x = 'Width' , y = 'count' , data = CD , label = 'Width of Cars',marker='o',s=80)
sns.scatterplot(x = 'Length' , y ='count' , data = DE , label = 'Length of Cars',marker='^',s=80)
plt.title('SCATTERED REPORT OF MAKERS BASED ON SIZE',fontsize=16, color='purple')
plt.xlabel('Width and length of CARS' , color = 'blue')
plt.ylabel('No. of Counts according to their size' , color = 'red')
plt.xticks(rotation = 90 , color = 'brown')
plt.yticks(rotation = 45 , color = 'orange')
plt.tight_layout()
plt.grid(alpha = 0.8)
plt.show()

# %%
#CHECKING WIDTH OF CD USING HISTPLOT
sns.histplot(CD['Width'] , kde = True , bins = 10)
# Out:
# <Axes: xlabel='Width', ylabel='Count'>

# %%
#CHECKING LENGTH OF CD USING HISTPLOT
sns.histplot(DE['Length'] , kde = True )
# Out:
# <Axes: xlabel='Length', ylabel='Count'>

# %%
#COMBINED DATA HISTPLOT OF X
sns.histplot(EF['count_x'] , kde = True )
# Out:
# <Axes: xlabel='count_x', ylabel='Count'>

# %%
#COMBINED DATA HISTPLOT OF Y
sns.histplot(EF['count_y'] , kde = True )
# Out:
# <Axes: xlabel='count_y', ylabel='Count'>

# %%
A.head()
# Out:
#      Maker  Genmodel  Genmodel_ID   Adv_ID  Adv_year  Adv_month   Color  \
# 0  Bentley    Arnage         10_1  10_1$$1      2018          4  Silver
# 1  Bentley    Arnage         10_1  10_1$$2      2018          6    Grey
# 2  Bentley    Arnage         10_1  10_1$$3      2017         11    Blue
# 3  Bentley    Arnage         10_1  10_1$$4      2018          4   Green
# 4  Bentley    Arnage         10_1  10_1$$5      2017         11    Grey
#
#    Reg_year Bodytype Runned_Miles Engin_size    Gearbox Fuel_type    Price  \
# 0    2000.0   Saloon        60000       6.8L  Automatic    Petrol  21500.0
# 1    2002.0   Saloon        44000       6.8L  Automatic    Petrol  28750.0
# 2    2002.0   Saloon        55000       6.8L  Automatic    Petrol  29999.0
# 3    2003.0   Saloon        14000       6.8L  Automatic    Petrol  34948.0
# 4    2003.0   Saloon        61652       6.8L  Automatic    Petrol  26555.0
#
#    Engine_power Annual_Tax  Wheelbase  Height   Width  Length Average_mpg  \
# ...

# %%
A['Width'].isnull().sum()
# Out:
# np.int64(28080)

# %%
A['Price'] = A['Price'].fillna(A['Price'].mean())

# %%
A.isnull().any()
# Out:
# Maker                 False
#  Genmodel             False
#  Genmodel_ID          False
# Adv_ID                False
# Adv_year              False
# Adv_month             False
# Color                  True
# Reg_year               True
# Bodytype               True
# Runned_Miles           True
# Engin_size             True
# Gearbox                True
# Fuel_type              True
# Price                 False
# Engine_power           True
# Annual_Tax             True
# Wheelbase             False
# Height                 True
# Width                  True
# Length                False
# Average_mpg            True
# Top_speed              True
# Seat_num               True
# Door_num               True
# Extra_Runned_Miles     True
# dtype: bool

# %%
A['Door_num'].unique()
# Out:
# array([ 4., nan,  5.,  2.,  3.,  6.,  7.,  0.])

# %%
A.drop(columns = ['Annual_Tax','Average_mpg','Wheelbase','Top_speed','Adv_ID','Extra_Runned_Miles'],axis = 1,inplace = True)

# %%
sns.boxplot(A['Engine_power'])
# Out:
# <Axes: ylabel='Engine_power'>

# %%
A['Runned_Miles	'] = A['Runned_Miles'].fillna(A['Runned_Miles'].mode()[0])

# %%
A.head()
# Out:
#       Maker  Genmodel  Genmodel_ID  Adv_year  Adv_month   Color  Reg_year  \
# 1   Bentley    Arnage         10_1      2018          6    Grey    2002.0
# 2   Bentley    Arnage         10_1      2017         11    Blue    2002.0
# 5   Bentley    Arnage         10_1      2017         12    Blue    2002.0
# 6   Bentley    Arnage         10_1      2018          8   Green    2002.0
# 11  Bentley    Arnage         10_1      2018          6  Silver    2002.0
#
#    Bodytype Engin_size    Gearbox Fuel_type    Price  Engine_power  Height  \
# 1    Saloon       6.8L  Automatic    Petrol  28750.0         450.0  1515.0
# 2    Saloon       6.8L  Automatic    Petrol  29999.0         400.0  1515.0
# 5    Saloon       6.8L  Automatic    Petrol  24950.0         450.0  1515.0
# 6    Saloon       6.8L  Automatic    Petrol  29995.0         450.0  1515.0
# 11   Saloon       6.8L  Automatic    Petrol  26990.0         450.0  1515.0
#
#      Width  Length  Seat_num  Door_num Runned_Miles\t
# ...

# %%
A.drop(columns = [' Genmodel_ID'],axis = 1,inplace = True)
